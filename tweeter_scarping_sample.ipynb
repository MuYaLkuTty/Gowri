# %% [markdown]
# <a href="https://colab.research.google.com/github/MuYaLkuTty/Gowri/blob/main/tweeter_scarping_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 2.9 MB/s eta 0:00:00
# ...

# %%
import snscrape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-c5de32ed58f1> in <module>
# ----> 1 import snscrape
#
# ModuleNotFoundError: No module named 'snscrape'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Select database and collection
db = client["twitter_data"]
collection = db["tweets"]

# Insert data
data = {"date": "2022-03-03", "id": "123456789", "tweet": "Hello, world!"}
collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-99190630242e> in <module>
#      10 # Insert data
#      11 data = {"date": "2022-03-03", "id": "123456789", "tweet": "Hello, world!"}
# ---> 12 collection.insert_many(data)
#
# /usr/local/lib/python3.8/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.8/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     696             or not documents
#     697         ):
# --> 698             raise TypeError("documents must be a non-empty list")
# ...

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 20.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 8.9 MB/s eta 0:00:00
# ...

# %%
# !streamlit hello
# Out:
# ...
#
#
#   Welcome to Streamlit. Check out our demo in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.231.32.145:8501
#
#   Ready to create your own Python apps super quickly?
#   Head over to https://docs.streamlit.io
#
#   May you create awesome apps!

# %%
import streamlit as st

# %%
# !pip install matplotlib-venn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
streamlit run /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py
# Out:
#   File "<ipython-input-13-81d8481abc4d>", line 1
#     streamlit run /usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Define keyword, date range, and tweet count limit
keyword = "elon musk"
since_date = "2022-01-01"
until_date = "2022-02-28"
tweet_limit = 1000

# Define list to store scraped data
tweets_list = []

# Define query to search for tweets
query = f"{keyword} since:{since_date} until:{until_date} lang:en"

# Loop through the scraped tweets and append them to the list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    if i >= tweet_limit:
        break
    tweets_list.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.replyCount, tweet.retweetCount, tweet.lang, tweet.source, tweet.likeCount])

# Convert list to dataframe
tweets_df = pd.DataFrame(tweets_list, columns=["date", "id", "url", "content", "user", "reply_count", "retweet_count", "language", "source", "like_count"])
# Out:
# INFO:snscrape.modules.twitter:Retrieving scroll page None
# 2023-03-04 07:13:46.568 Retrieving scroll page None
# INFO:snscrape.modules.twitter:Retrieving guest token
# 2023-03-04 07:13:46.585 Retrieving guest token
# INFO:snscrape.base:Retrieving https://twitter.com/search?f=live&lang=en&q=elon+musk+since%3A2022-01-01+until%3A2022-02-28+lang%3Aen&src=spelling_expansion_revert_click
# 2023-03-04 07:13:46.608 Retrieving https://twitter.com/search?f=live&lang=en&q=elon+musk+since%3A2022-01-01+until%3A2022-02-28+lang%3Aen&src=spelling_expansion_revert_click
# INFO:snscrape.base:Retrieved https://twitter.com/search?f=live&lang=en&q=elon+musk+since%3A2022-01-01+until%3A2022-02-28+lang%3Aen&src=spelling_expansion_revert_click: 200
# 2023-03-04 07:13:46.850 Retrieved https://twitter.com/search?f=live&lang=en&q=elon+musk+since%3A2022-01-01+until%3A2022-02-28+lang%3Aen&src=spelling_expansion_revert_click: 200
# INFO:snscrape.modules.twitter:Retrieving guest token via API
# ...

# %%
tweets_df
# Out:
#                          date                   id  \
# 0   2022-02-27 23:59:57+00:00  1498085527182053380
# 1   2022-02-27 23:59:48+00:00  1498085490133635073
# 2   2022-02-27 23:59:45+00:00  1498085476594450437
# 3   2022-02-27 23:59:43+00:00  1498085469342638092
# 4   2022-02-27 23:59:43+00:00  1498085469199818753
# ..                        ...                  ...
# 995 2022-02-27 23:02:18+00:00  1498071017583001601
# 996 2022-02-27 23:02:16+00:00  1498071010574319618
# 997 2022-02-27 23:02:11+00:00  1498070988084318210
# 998 2022-02-27 23:02:09+00:00  1498070980358463497
# 999 2022-02-27 23:02:08+00:00  1498070976130691074
#
#                                                    url  \
# 0    https://twitter.com/wardvo/status/149808552718...
# 1    https://twitter.com/Jaccuse1/status/1498085490...
# 2    https://twitter.com/Jameslim1234567/status/149...
# 3    https://twitter.com/KingGuy04/status/149808546...
# 4    https://twitter.com/MarcusPun/status/149808546...
# ...

# %%
# Import PyMongo library
from pymongo import MongoClient

# Connect to MongoDB database
client = MongoClient('<your_mongodb_uri>')
db = client['<your_database_name>']

# Get the collection from the database
collection = db['<your_collection_name>']

# Create a sample data dictionary
data = {
    'name': 'John Doe',
    'age': 30,
    'city': 'New York'
}

# Insert the data to the collection
collection.insert_one(data)

# Print success message
print('Data saved to MongoDB.')

# %%
query
# Out:
# 'elon musk since:2022-01-01 until:2022-02-28 lang:en'
